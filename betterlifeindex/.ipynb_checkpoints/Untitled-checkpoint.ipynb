# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn.linear_model

pd.set_option('display.max_columns',50)
oecd_bli=pd.read_csv("D:\\MLtbpractice\\betterlifeindex\\betterlifeindex.csv",thousands=',')
gdp_per_capita=pd.read_csv("WEO_Data.csv",thousands=',',delimiter=',',encoding='latin1',na_values="n/a")

# %%
country_stats=prepare_country_stats(oecd_bli,gdp_per_capita)
X=np.c_[country_stats["GDP per capita"]]
y=np.c_[country_stats["Life satisfaction"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-9f28a43e9fd2> in <module>
# ----> 1 country_stats=prepare_country_stats(oecd_bli,gdp_per_capita)
#       2 X=np.c_[country_stats["GDP per capita"]]
#       3 y=np.c_[country_stats["Life satisfaction"]]
#
# <ipython-input-77-01241d43f4f4> in prepare_country_stats(oecd_bli, gdp_per_capita)
#       4     oecd_bli=oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
#       5     gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
# ----> 6     gdp_per_capita.set_index("Country", inplace=True)
#       7     full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
#       8                                   left_index=True, right_index=True)
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Country'] are in the columns"

# %%
oecd_bli.head(5)
# Out:
#   LOCATION         Country INDICATOR                 Indicator MEASURE  \
# 0      AUS       Australia   JE_LMIS  Labour market insecurity       L
# 1      AUT         Austria   JE_LMIS  Labour market insecurity       L
# 2      BEL         Belgium   JE_LMIS  Labour market insecurity       L
# 3      CAN          Canada   JE_LMIS  Labour market insecurity       L
# 4      CZE  Czech Republic   JE_LMIS  Labour market insecurity       L
#
#   Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0   Value        TOT      Total        PC  Percentage               0
# 1   Value        TOT      Total        PC  Percentage               0
# 2   Value        TOT      Total        PC  Percentage               0
# 3   Value        TOT      Total        PC  Percentage               0
# 4   Value        TOT      Total        PC  Percentage               0
#
#   PowerCode  Reference Period Code  Reference Period  Value  Flag Codes  Flags
# 0     Units                    NaN               NaN    5.4         NaN    NaN
# 1     Units                    NaN               NaN    3.5         NaN    NaN
# 2     Units                    NaN               NaN    3.7         NaN    NaN
# 3     Units                    NaN               NaN    6.0         NaN    NaN
# 4     Units                    NaN               NaN    3.1         NaN    NaN

# %%
gdp_per_capita.head(5)
# Out:
#                Country                                 Subject Descriptor  \
# 0          Afghanistan  Gross domestic product per capita, current prices
# 1              Albania  Gross domestic product per capita, current prices
# 2              Algeria  Gross domestic product per capita, current prices
# 3               Angola  Gross domestic product per capita, current prices
# 4  Antigua and Barbuda  Gross domestic product per capita, current prices
#
#           Units  Scale                      Country/Series-specific Notes  \
# 0  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 1  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 2  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 3  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 4  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
#
#         2015  Estimates Start After
# 0    599.994                 2013.0
# 1   3995.380                 2010.0
# 2   4318.140                 2014.0
# 3   4100.320                 2014.0
# 4  14414.300                 2011.0

# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    oecd_bli=oecd_bli[oecd_bli['INEQUALITY']=='TOT']
    oecd_bli=oecd_bli[oecd_bli['INEQUALITY']=='TOT']
    oecd_bli=oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    remove_indices = [0, 1, 6, 8, 33, 34,35]
    keep_indices = list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]

# %%
full_country_stats.iloc[[0, 1, 6, 8, 33, 34, 35]]
# Out:
#               Air pollution  Dwellings without basic facilities  \
# Country
# South Africa           22.0                                37.0
# Colombia               10.0                                23.9
# Hungary                19.0                                 4.7
# Chile                  16.0                                 9.4
# Australia               5.0                                 NaN
# Ireland                 7.0                                 1.0
# Denmark                 9.0                                 0.5
#
#               Educational attainment  Employees working very long hours  \
# Country
# South Africa                    73.0                              18.12
# Colombia                        54.0                              26.56
# Hungary                         84.0                               3.03
# Chile                           65.0                               9.72
# Australia                       81.0                              13.04
# Ireland                         82.0                               5.25
# Denmark                         81.0                               2.34
#
#               Employment rate  Feeling safe walking alone at night  \
# Country
# South Africa             43.0                                 36.1
# Colombia                 67.0                                 44.4
# Hungary                  68.0                                 56.3
# Chile                    63.0                                 47.9
# Australia                73.0                                 63.5
# Ireland                  67.0                                 75.9
# Denmark                  74.0                                 83.5
#
#               Homicide rate  Household net adjusted disposable income  \
# Country
# South Africa           13.7                                       NaN
# Colombia               24.5                                       NaN
# Hungary                 1.0                                       NaN
# Chile                   4.2                                       NaN
# Australia               1.1                                   32759.0
# Ireland                 0.7                                   25310.0
# Denmark                 0.6                                   29606.0
#
#               Household net wealth  Housing expenditure  \
# Country
# South Africa                   NaN                 18.0
# Colombia                       NaN                 17.0
# Hungary                   104458.0                 19.0
# Chile                     100967.0                 18.0
# Australia                 427064.0                 20.0
# Ireland                   217130.0                 20.0
# Denmark                   118637.0                 23.0
#
#               Labour market insecurity  Life expectancy  Life satisfaction  \
# Country
# South Africa                       NaN             57.5                4.7
# Colombia                           NaN             76.2                6.3
# Hungary                            4.7             76.2                5.6
# Chile                              8.7             79.9                6.5
# Australia                          5.4             82.5                7.3
# Ireland                            7.8             81.8                7.0
# Denmark                            4.2             80.9                7.6
#
#               Long-term unemployment rate  Personal earnings  \
# Country
# South Africa                        16.46                NaN
# Colombia                             0.79                NaN
# Hungary                              1.72            22576.0
# Chile                                 NaN            25879.0
# Australia                            1.31            49126.0
# Ireland                              3.23            47653.0
# Denmark                              1.31            51466.0
#
#               Quality of support network  Rooms per person  \
# Country
# South Africa                        88.0               NaN
# Colombia                            89.0               1.2
# Hungary                             86.0               1.2
# Chile                               85.0               1.2
# Australia                           95.0               NaN
# Ireland                             95.0               2.1
# Denmark                             95.0               1.9
#
#               Self-reported health  \
# Country
# South Africa                   NaN
# Colombia                       NaN
# Hungary                       60.0
# Chile                         57.0
# Australia                     85.0
# Ireland                       83.0
# Denmark                       71.0
#
#               Stakeholder engagement for developing regulations  \
# Country
# South Africa                                                NaN
# Colombia                                                    1.4
# Hungary                                                     1.2
# Chile                                                       1.3
# Australia                                                   2.7
# Ireland                                                     1.3
# Denmark                                                     2.0
#
#               Student skills  Time devoted to leisure and personal care  \
# Country
# South Africa             NaN                                      14.92
# Colombia               410.0                                        NaN
# Hungary                474.0                                        NaN
# Chile                  443.0                                        NaN
# Australia              502.0                                      14.35
# Ireland                509.0                                        NaN
# Denmark                504.0                                      15.87
#
#               Voter turnout  Water quality  Years in education  \
# Country
# South Africa           73.0           67.0                 NaN
# Colombia               53.0           75.0                14.1
# Hungary                70.0           77.0                16.4
# Chile                  47.0           71.0                17.5
# Australia              91.0           93.0                21.0
# Ireland                65.0           85.0                18.1
# Denmark                86.0           95.0                19.5
#
#                                              Subject Descriptor         Units  \
# Country
# South Africa  Gross domestic product per capita, current prices  U.S. dollars
# Colombia      Gross domestic product per capita, current prices  U.S. dollars
# Hungary       Gross domestic product per capita, current prices  U.S. dollars
# Chile         Gross domestic product per capita, current prices  U.S. dollars
# Australia     Gross domestic product per capita, current prices  U.S. dollars
# Ireland       Gross domestic product per capita, current prices  U.S. dollars
# Denmark       Gross domestic product per capita, current prices  U.S. dollars
#
#               Scale                      Country/Series-specific Notes  \
# Country
# South Africa  Units  See notes for:  Gross domestic product, curren...
# Colombia      Units  See notes for:  Gross domestic product, curren...
# Hungary       Units  See notes for:  Gross domestic product, curren...
# Chile         Units  See notes for:  Gross domestic product, curren...
# Australia     Units  See notes for:  Gross domestic product, curren...
# Ireland       Units  See notes for:  Gross domestic product, curren...
# Denmark       Units  See notes for:  Gross domestic product, curren...
#
#               GDP per capita  Estimates Start After
# Country
# South Africa         5694.57                 2014.0
# Colombia             6083.51                 2014.0
# Hungary             12239.89                 2015.0
# Chile               13340.91                 2014.0
# Australia           50961.87                 2014.0
# Ireland             51350.74                 2014.0
# Denmark             52114.17                 2015.0

# %%
country_stats.plot(kind='scatter',x="GDP per capita",y='Life satisfaction')
plt.show()

# %%
model=sklearn.linear_model.LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_new=[[22587]]

# %%
print(model.predict(X_new))
# Out:
# [[6.2616783]]
